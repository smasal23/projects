# %% [markdown]
# ## 🚀 ERIA Orchestrator Test (End-to-End)
#
# This cell validates:
# - LLM response generation
# - JSON parsing
# - Schema validation
# - Hallucination detection
#
# ---

# %%
# ================================
# ERIA ORCHESTRATOR TEST (CLEAN)
# ================================

from src.analysis.orchestrator import ERIAOrchestrator
import json

# -------------------------------
# 1. Initialize
# -------------------------------
engine = ERIAOrchestrator()

# -------------------------------
# 2. Sample Input
# -------------------------------
sample_text = """
The Prime Minister Internship Scheme was launched in Budget 2024-25
to provide internship opportunities to youth in top companies.
It offers monthly financial assistance and skill development exposure.
"""

# -------------------------------
# 3. Run Pipeline
# -------------------------------
result = engine.run(sample_text)

# -------------------------------
# 4. Print Raw Output
# -------------------------------
print("\n================ OUTPUT ================\n")
print(json.dumps(result, indent=2))

# -------------------------------
# 5. Basic Success Check
# -------------------------------
print("\n================ STATUS ================\n")

if not isinstance(result, dict):
    print("❌ Output is not a dictionary")

elif "error" in result:
    print("❌ Pipeline Failed")
    print(result)

else:
    print("✅ JSON Parsed Successfully")

# -------------------------------
# 6. Key Presence Check
# -------------------------------
print("\n================ KEYS ================\n")

expected_keys = [
    "regulation_topic",
    "chronology",
    "impact_analysis",
    "sentiment_risk",
    "summary",
    "stakeholder_report",
    "impact_assessment",
    "positives",
    "negatives"
]

if isinstance(result, dict) and "error" not in result:
    missing = [k for k in expected_keys if k not in result]

    if not missing:
        print("✅ All expected keys present")
    else:
        print("⚠️ Missing keys:", missing)

    print("\nAvailable keys:", list(result.keys()))
# Out:
# 🔍 RAW RESPONSE:
#  {{
#   "regulation_topic": "Prime Minister Internship Scheme",
#
#   "chronology": {
#     "predecessor_circulars": ["The scheme was announced in Budget 2024-25 to promote youth development"],
#     "amendments": ["No amendments have been made to the scheme as of now"],
#     "historical_context": ["The scheme aims to address the need for skilled workforce in top companies"]
#   },
#
#   "impact_analysis": {
#     "students": ["The scheme provides internship opportunities to youth in top companies for skill devel
#
# ⚠️ Parser failed — retrying once...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 25
#      16 sample_text = """
#      17 The Prime Minister Internship Scheme was launched in Budget 2024-25
#      18 to provide internship opportunities to youth in top companies.
# ...
